# %%
import pandas as pd

df = pd.read_csv("courses.csv")
display(df)
# Out:
#    Course_#                                               Name  \
# 0       201                Introduction to Information Science
# 1       126  Introduction to Programming for Information Sc...
# 2       311                           Information Organization
# 3       311                           Information Organization
# 4       314                 Statistics for Information Science
# 5       326  Object-Oriented Programming for Information Sc...
# 6       327                       Database Design and Modeling
# 7       NaN                                                NaN
# 8       123                                  Databases for All
# 9       152  "Fake Checking": Battling Misinformation and D...
# 10      154                                       Apollo at 50
# 11      155                                  Social Networking
# 12      NaN                                                NaN
# 13     208A  Special Topics in Information Studies; HOW NAS...
# 14     208M  Special Topics in Information Studies; Academi...
# 15      NaN                                                NaN
# 16      309           Independent Study in Information Science
# 17      311                           Information Organization
# 18      314                 Statistics for Information Science
# 19      326  Object-Oriented Programming for Information Sc...
# 20      327                       Database Design and Modeling
# 21      335             Organizations, Management and Teamwork
# 22      346      Technologies, Infrastructure and Architecture
# 23      352              Information User Needs and Assessment
# 24      354            Decision-Making for Information Science
# 25      362                               User-Centered Design
# 26      366          Privacy, Security and Ethics for Big Data
# 27      377                           Dynamic Web Applications
# 28      NaN                                                NaN
# 29     408D  Special Topics in Information Science; Designi...
# 30     408F  Special Topics in Information Science; Health ...
# 31     408K  Special Topics in Information Science; Competi...
# 32     408M  Special Topics in Information Science; Design ...
# 33     408P  Special Topics in Information Science; Introdu...
# 34     408R  Special Topics in Information Science; Human-C...
# 35      414                            Data Science Techniques
# 36      441                      Information Ethics and Policy
# 37      443             Tools and Methods for Digital Curation
# 38      447                      Data Sources and Manipulation
# 39      462                 Introduction to Data Visualization
# 40      464                  Decision Making for Cybersecurity
# 41      466                   Technology, Culture, and Society
# 42      467                Practical Hacking for Policy Makers
# 43      490        Integrated Capstone for Information Science
# 44      NaN                                                NaN
# 45      604      Introduction to Archives and Digital Curation
# 46     608J  Special Topics in Information Studies; Game De...
# 47      612                                 Information Policy
# 48      614                             Literacy and Inclusion
# 49      616                           Open Source Intelligence
# 50      622                Information and Universal Usability
#
#    Average_Semester_Grade  Pass_Rate          Professor Professor_Rating  \
# 0                      89        NaN             Sauter               93
# 1                      85        NaN              Piety               70
# 2                      85         83              Byers               95
# 3                      87         90            Hawkins               97
# 4                      85         92              Brown               90
# 5                      80         85             Dustin               89
# 6                      88         96                NaN              NaN
# 7                     NaN        NaN                NaN              NaN
# 8                      93        NaN              Duffy               86
# 9                      88        NaN  Gorham-Oscilowski               92
# 10                     83        NaN               Oard               60
# 11                     88        NaN            Golbeck               70
# 12                    NaN        NaN                NaN              NaN
# 13                     86        NaN             Skakun              NaN
# 14                     95        NaN                TBA              NaN
# 15                    NaN        NaN                NaN              NaN
# 16                     89         93               Chan              100
# 17                     87         96            O'Grady               80
# 18                     75         92             Janzen              100
# 19                     77         91              Bills              100
# 20                     86         95              Duffy              100
# 21                     80         91             Paletz              100
# 22                     88         96         Heidenblad               70
# 23                     92         96            Gammons              100
# 24                     85         96             Weaver               60
# 25                     94         99                NaN              100
# 26                     86         95              Vitak              100
# 27                     77         85             Leitch               60
# 28                    NaN        NaN                NaN              NaN
# 29                     82         75               Choe              NaN
# 30                     96         82             Sigalo              100
# 31                     90         73               Shah               80
# 32                    NaN        NaN             Conrad              NaN
# 33                    NaN        NaN                TBA              NaN
# 34                    NaN        NaN                Gao              NaN
# 35                     75         85      Ravindra-Bhat               93
# 36                     93         85             Sauter              100
# 37                     95         85           Marciano              NaN
# 38                     71         85      Ravindra-Bhat               93
# 39                     89         95            Golbeck               60
# 40                     91         98           Campbell              100
# 41                     86         97              Piety              NaN
# 42                     89         96              Harry              NaN
# 43                     97        100          Rainsford              100
# 44                    gpa  pass rate                NaN      prof rating
# 45                     93         93              Marsh              NaN
# 46                     94         97           Elmqvist              NaN
# 47                     94         94             Jaeger              NaN
# 48                     94         98               Adle              NaN
# 49                     94         86            Francis              NaN
# 50                     94         93               Hill              100
#
#        Format
# 0      Online
# 1      Online
# 2      Online
# 3     Blended
# 4   In-Person
# 5     Blended
# 6         NaN
# 7         NaN
# 8      Online
# 9      Online
# 10     Online
# 11     Online
# 12        NaN
# 13     Online
# 14        TBA
# 15        NaN
# 16        TBA
# 17     Online
# 18     Online
# 19     Online
# 20     Online
# 21     Online
# 22    Blended
# 23    Blended
# 24    Blended
# 25     Online
# 26     Online
# 27     Online
# 28        NaN
# 29     Online
# 30     Online
# 31     Online
# 32        NaN
# 33        NaN
# 34        NaN
# 35     Online
# 36     Online
# 37     Online
# 38     Online
# 39     Online
# 40     Online
# 41     Online
# 42     Online
# 43     Online
# 44        NaN
# 45     Online
# 46     Online
# 47     Online
# 48     Online
# 49     Online
# 50     Online

# %%
def sort_courses():
    
    print("Please choose to sort by one of the following:")
    key_word = input("Course Number, Name, Avg. Semester Grade, Pass Rate, Professor, Professor Rating, or Format")
    
    if key_word == "Course Number":
        co_num_df = df.sort_values(by='Course_#')
        display(co_num_df)
    elif key_word == "Name":
        name_df = df.sort_values(by='Name')
        display(name_df)
    elif key_word == "Avg. Semester Grade":
        grade_df = df.sort_values(by='Average_Semester_Grade')
        display(grade_df)
    elif key_word == "Pass Rate":
        pass_df = df.sort_values(by='Pass_Rate')
        display(pass_df)
    elif key_word == "Professor":
        prof_df = df.sort_values(by='Professor')
        display(prof_df)
    elif key_word == "Professor Rating":
        prof_rate_df = df.sort_values(by='Professor_Rating')
        display(prof_rate_df)
    elif key_word == "Format":
        form_df = df.sort_values(by='Format')
        display(form_df)

# %%
def search_courses():
    
    print("Please choose to search one of the following:")
    key_word = input("Course Number, Name, Avg. Semester Grade, Pass Rate, Professor, or Format")
    search_term = input("Now, enter your search criteria:")
    
    if key_word == "Course Number":
        co_num_df = df[df['Course_#'] == int(search_term)]
        display(co_num_df)
    elif key_word == "Name":
        name_df = df[df['Name'] == search_term]
        display(name_df)
    elif key_word == "Avg. Semester Grade":
        grade_df = df[df['Average_Semester_Grade'] == int(search_term)]
        display(grade_df)
    elif key_word == "Pass Rate":
        pass_df = df[df['Pass_Rate'] == int(search_term)]
        display(pass_df)
    elif key_word == "Professor":
        prof_df = df[df['Professor'] == search_term]
        display(prof_df)
    elif key_word == "Format":
        form_df = df[df['Format'] == search_term]
        display(form_df)

# %%
def save_courses(save_option):
    
    saving = True
    
    if save_option == "Yes":
        while saving == True:
            num = input("Enter the leftmost value of the course you would like to save.")
            saved_courses.append(int(num))
            save_option = input("Continue? Yes or No.")
            if save_option == "No":
                saving = False

# %%
def function_select(option):
    
    running = True
    not_First = True
    
    while running == True:
        
        if not_First == False:
            option = input("Would you like to sort or search?")
            
        if option == "Sort":
            sort_courses()
        elif option == "Search":
            search_courses()
        else:
            print("Invalid Option")
            
        save_option = input("Would you like to save a course? Yes or No.")
        save_courses(save_option)
            
        cont_running = input("Would you like to continue running the program? Yes or No.")
        if cont_running == "No":
            running = False
            for i in saved_courses:
                print(f"{df.iloc[i]}\n----------------------\n")
                
        not_First = False

# %%
global saved_courses
saved_courses = []

option = input("Would you like to sort or search?")
function_select(option)
# Out:
# Would you like to sort or search? Sort
# Please choose to sort by one of the following:
# Course Number, Name, Avg. Semester Grade, Pass Rate, Professor, Professor Rating, or Format Name
#    Course_#                                               Name  \
# 9       152  "Fake Checking": Battling Misinformation and D...
# 10      154                                       Apollo at 50
# 35      414                            Data Science Techniques
# 38      447                      Data Sources and Manipulation
# 20      327                       Database Design and Modeling
# 6       327                       Database Design and Modeling
# 8       123                                  Databases for All
# 40      464                  Decision Making for Cybersecurity
# 24      354            Decision-Making for Information Science
# 27      377                           Dynamic Web Applications
# 16      309           Independent Study in Information Science
# 36      441                      Information Ethics and Policy
# 2       311                           Information Organization
# 3       311                           Information Organization
# 17      311                           Information Organization
# 47      612                                 Information Policy
# 23      352              Information User Needs and Assessment
# 50      622                Information and Universal Usability
# 43      490        Integrated Capstone for Information Science
# 45      604      Introduction to Archives and Digital Curation
# 39      462                 Introduction to Data Visualization
# 0       201                Introduction to Information Science
# 1       126  Introduction to Programming for Information Sc...
# 48      614                             Literacy and Inclusion
# 5       326  Object-Oriented Programming for Information Sc...
# 19      326  Object-Oriented Programming for Information Sc...
# 49      616                           Open Source Intelligence
# 21      335             Organizations, Management and Teamwork
# 42      467                Practical Hacking for Policy Makers
# 26      366          Privacy, Security and Ethics for Big Data
# 11      155                                  Social Networking
# 31     408K  Special Topics in Information Science; Competi...
# 32     408M  Special Topics in Information Science; Design ...
# 29     408D  Special Topics in Information Science; Designi...
# 30     408F  Special Topics in Information Science; Health ...
# 34     408R  Special Topics in Information Science; Human-C...
# 33     408P  Special Topics in Information Science; Introdu...
# 14     208M  Special Topics in Information Studies; Academi...
# 46     608J  Special Topics in Information Studies; Game De...
# 13     208A  Special Topics in Information Studies; HOW NAS...
# 4       314                 Statistics for Information Science
# 18      314                 Statistics for Information Science
# 22      346      Technologies, Infrastructure and Architecture
# 41      466                   Technology, Culture, and Society
# 37      443             Tools and Methods for Digital Curation
# 25      362                               User-Centered Design
# 7       NaN                                                NaN
# 12      NaN                                                NaN
# 15      NaN                                                NaN
# 28      NaN                                                NaN
# 44      NaN                                                NaN
#
#    Average_Semester_Grade  Pass_Rate          Professor Professor_Rating  \
# 9                      88        NaN  Gorham-Oscilowski               92
# 10                     83        NaN               Oard               60
# 35                     75         85      Ravindra-Bhat               93
# 38                     71         85      Ravindra-Bhat               93
# 20                     86         95              Duffy              100
# 6                      88         96                NaN              NaN
# 8                      93        NaN              Duffy               86
# 40                     91         98           Campbell              100
# 24                     85         96             Weaver               60
# 27                     77         85             Leitch               60
# 16                     89         93               Chan              100
# 36                     93         85             Sauter              100
# 2                      85         83              Byers               95
# 3                      87         90            Hawkins               97
# 17                     87         96            O'Grady               80
# 47                     94         94             Jaeger              NaN
# 23                     92         96            Gammons              100
# 50                     94         93               Hill              100
# 43                     97        100          Rainsford              100
# 45                     93         93              Marsh              NaN
# 39                     89         95            Golbeck               60
# 0                      89        NaN             Sauter               93
# 1                      85        NaN              Piety               70
# 48                     94         98               Adle              NaN
# 5                      80         85             Dustin               89
# 19                     77         91              Bills              100
# 49                     94         86            Francis              NaN
# 21                     80         91             Paletz              100
# 42                     89         96              Harry              NaN
# 26                     86         95              Vitak              100
# 11                     88        NaN            Golbeck               70
# 31                     90         73               Shah               80
# 32                    NaN        NaN             Conrad              NaN
# 29                     82         75               Choe              NaN
# 30                     96         82             Sigalo              100
# 34                    NaN        NaN                Gao              NaN
# 33                    NaN        NaN                TBA              NaN
# 14                     95        NaN                TBA              NaN
# 46                     94         97           Elmqvist              NaN
# 13                     86        NaN             Skakun              NaN
# 4                      85         92              Brown               90
# 18                     75         92             Janzen              100
# 22                     88         96         Heidenblad               70
# 41                     86         97              Piety              NaN
# 37                     95         85           Marciano              NaN
# 25                     94         99                NaN              100
# 7                     NaN        NaN                NaN              NaN
# 12                    NaN        NaN                NaN              NaN
# 15                    NaN        NaN                NaN              NaN
# 28                    NaN        NaN                NaN              NaN
# 44                    gpa  pass rate                NaN      prof rating
#
#        Format
# 9      Online
# 10     Online
# 35     Online
# 38     Online
# 20     Online
# 6         NaN
# 8      Online
# 40     Online
# 24    Blended
# 27     Online
# 16        TBA
# 36     Online
# 2      Online
# 3     Blended
# 17     Online
# 47     Online
# 23    Blended
# 50     Online
# 43     Online
# 45     Online
# 39     Online
# 0      Online
# 1      Online
# 48     Online
# 5     Blended
# 19     Online
# 49     Online
# 21     Online
# 42     Online
# 26     Online
# 11     Online
# 31     Online
# 32        NaN
# 29     Online
# 30     Online
# 34        NaN
# 33        NaN
# 14        TBA
# 46     Online
# 13     Online
# 4   In-Person
# 18     Online
# 22    Blended
# 41     Online
# 37     Online
# 25     Online
# 7         NaN
# 12        NaN
# 15        NaN
# 28        NaN
# 44        NaN
# Would you like to save a course? Yes or No. Yes
# Enter the leftmost value of the course you would like to save. 2
# Continue? Yes or No. Yes
# Enter the leftmost value of the course you would like to save. 3
# Continue? Yes or No. No
# Would you like to continue running the program? Yes or No. Yes
# Would you like to sort or search? Search
# Please choose to search one of the following:
# Course Number, Name, Avg. Semester Grade, Pass Rate, Professor, or Format Format
# Now, enter your search criteria: Blended
#    Course_#                                               Name  \
# 3       311                           Information Organization
# 5       326  Object-Oriented Programming for Information Sc...
# 22      346      Technologies, Infrastructure and Architecture
# 23      352              Information User Needs and Assessment
# 24      354            Decision-Making for Information Science
#
#    Average_Semester_Grade Pass_Rate   Professor Professor_Rating   Format
# 3                      87        90     Hawkins               97  Blended
# 5                      80        85      Dustin               89  Blended
# 22                     88        96  Heidenblad               70  Blended
# 23                     92        96     Gammons              100  Blended
# 24                     85        96      Weaver               60  Blended
# Would you like to save a course? Yes or No. Yes
# Enter the leftmost value of the course you would like to save. 5
# Continue? Yes or No. No
# Would you like to continue running the program? Yes or No. No
# Course_#                                       311
# Name                      Information Organization
# Average_Semester_Grade                          85
# Pass_Rate                                       83
# Professor                                    Byers
# Professor_Rating                                95
# Format                                      Online
# Name: 2, dtype: object
# ----------------------
#
# Course_#                                       311
# Name                      Information Organization
# Average_Semester_Grade                          87
# Pass_Rate                                       90
# Professor                                  Hawkins
# Professor_Rating                                97
# Format                                     Blended
# Name: 3, dtype: object
# ----------------------
#
# Course_#                                                                326
# Name                      Object-Oriented Programming for Information Sc...
# Average_Semester_Grade                                                   80
# Pass_Rate                                                                85
# Professor                                                            Dustin
# Professor_Rating                                                         89
# Format                                                              Blended
# Name: 5, dtype: object
# ----------------------
